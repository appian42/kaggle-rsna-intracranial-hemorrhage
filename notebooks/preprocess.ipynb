# %%
import os, sys, pickle
import numpy as np
import pandas as pd

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

os.chdir("..")

# %%
with open('./cache/test.pkl', 'rb') as f:
    df = pickle.load(f)
    
df.head()
# Out:
#                         ID labels   PatientID  WindowCenter  WindowWidth  \
# 12155  CQ500-CT-0_CT000000         CQ500-CT-0            30          100
# 11487  CQ500-CT-0_CT000001         CQ500-CT-0            30          100
# 20082  CQ500-CT-0_CT000002         CQ500-CT-0            30          100
# 19345  CQ500-CT-0_CT000003         CQ500-CT-0            30          100
# 21409  CQ500-CT-0_CT000004         CQ500-CT-0            30          100
#
#        RescaleIntercept  RescaleSlope  Position3  PositionOrd LeftLabel  \
# 12155           -1024.0           1.0     69.298     0.566667
# 11487           -1024.0           1.0     64.235     0.533333
# 20082           -1024.0           1.0    124.985     0.933333
# 19345           -1024.0           1.0    119.923     0.900000
# 21409           -1024.0           1.0    135.110     1.000000
#
#       RightLabel  BitsStored  PixelRepresentation  brain_ratio  brain_diff
# 12155                     16                    1     0.277184        80.0
# 11487                     16                    1     0.288597        80.0
# 20082                     16                    1     0.007320        80.0
# 19345                     16                    1     0.007233        80.0
# 21409                     16                    1     0.001358        80.0
